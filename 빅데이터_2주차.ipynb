# %% [markdown]
# <a href="https://colab.research.google.com/github/sinsun030508/bigdata/blob/main/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0_2%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 자료형뿐만 아니라 데이터 묶음을 처리하기에 편리한 리스트, 퓨플로 만듦

# %%
print("hello python")
# Out:
# hello python

# %%
print("Welcome to Data Science and Machine Learning")
# Out:
# Welcome to Data Science and Machine Learning

# %%
import matplotlib.image as mping
import matplotlib.pyplot as plt
img = mping.imread('/content/mydrive/prime_robot.png')
plt.imshow(img)

# %%
import matplotlib.image as mping
import matplotlib.pyplot as cat
cat = mping.imread('/content/mydrive/prime_cat.png')

plt.imshow(cat)

# %%
# !pwd
# Out:
# /content

# %%
# !ls -l /content/mydrive/
# Out:
# total 88
# -rw-r--r-- 1 root root 56128 Mar 16 06:22 prime_cat.png
# -rw-r--r-- 1 root root 31920 Mar 16 06:12 prime_robot.png

# %% [markdown]
# <img src="https://github.com/dongupak/BigDataAnalysis/blob/main/image/prime_robot.png?raw=true">

# %%
import pandas as pd

df = pd.read_csv('/content/mydrive/vehicle_prod.csv')
df.head(5)
# Out:
#   Unnamed: 0   2007   2008   2009   2010   2011
# 0      China   7.71   7.95  11.96  15.84  16.33
# 1         EU  19.02  17.71  15.00  16.70  17.48
# 2         US  10.47   8.45   5.58   7.60   8.40
# 3      Japan  10.87  10.83   7.55   9.09   7.88
# 4      Korea   4.04   3.78   3.45   4.20   4.62

# %%
import pandas as pd
df = pd.read_csv('/content/mydrive/부산광역시 남구_장애인복지시설현황_20251215.csv', encoding='euc-kr')

df.head(50)
# Out:
#              시 설 명                                             소재지  \
# 0          소화영아재활원                          부산광역시 남구 무민사로 19 (감만동)
# 1         성프란치스꼬의집                        부산광역시 남구 용소로14번길 41(대연동)
# 2      하나장애인직업재활시설             부산광역시 남구 용호로 154  용호데디칼센터 701호(용호동)
# 3         이룸직업재활센터                        부산광역시 남구 유엔로25번길 58(우암동)
# 4         남구장애인복지관                      부산광역시 남구 조각공원로11번길 38(대연동)
# 5      나사함발달장애인복지관                          부산광역시 남구 못골번영로 70(대연동)
# 6         아띠주간보호센터                       부산광역시 남구 석포로127번길 97(대연동)
# 7        나사함주간보호센터                          부산광역시 남구 못골번영로 70(대연동)
# 8       솔라피데주간보호센터                        부산광역시 남구 진남로 160-20(대연동)
# 9   남구장애인복지관주간보호센터                      부산광역시 남구 조각공원로11번길 38(대연동)
# 10     꿈터장애인주간보호센터                     부산광역시 남구 진남로96번나길 17-1(대연동)
# 11     다울장애인공동생활가정           부산광역시 남구 용소로64번길  72, 102호(대연동, 월드빌라)
# 12        밀알공동생활가정  부산광역시 남구 수영로39번가길 83, 101동 1205호(문현동, 대도라이프타운)
# ...

# %%
person = {'이름' : '홍길동', '나이' : 26, '몸무게' : 82}
print('person의 키들 : ', list(person.keys()))
print('person의 값 : ', list(person.values()))
print('person의 아이템 : ', list(person.items()))
# Out:
# person의 키들 :  ['이름', '나이', '몸무게']
# person의 값 :  ['홍길동', 26, 82]
# person의 아이템 :  [('이름', '홍길동'), ('나이', 26), ('몸무게', 82)]

# %%
num = int(input('정수를 입력하세요 : '))
fact = 1
for i in range(1, num+1):
  fact = fact * i
print(f"{num}!은 {fact}입니다")
# Out:
# 정수를 입력하세요 : 5
# 5!은 120입니다

# %%
num = int(input("정수를 입력하시오"))
fact = 1
sum = 0
for i in range(1, num+1):
  fact = fact * i
  sum = sum + i
print(f"{num}!은 {fact}입니다 누적값은 {sum} 입니다")
# Out:
# 정수를 입력하시오10
# 10!은 3628800입니다 누적값은 56 입니다
