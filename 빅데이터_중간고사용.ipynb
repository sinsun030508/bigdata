# %% [markdown]
# <a href="https://colab.research.google.com/github/sinsun030508/bigdata/blob/main/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A4%91%EA%B0%84%EA%B3%A0%EC%82%AC%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2.1 데이터 과학을 위한 대표적인 프로그래밍 언어인 (   ) 은 귀도 반 로썸에 의해 개발된 객체 지향 프로그래밍 언어이다.

# %% [markdown]
# 2.2 파이썬의 특징 중 하나는 정부, 보동소수점, 문자와 같은 전통적인 (   ) 뿐만 아니라, 뎅터 묶음을 처리하기에 편리한 리스트, 퓨플, 딕셔너리, 집합과 같은 자료형을 기본으로 제공한다는 점이다.

# %% [markdown]
# # 빈칸 넣기 문제
#
#
# 2.1-2.13
# 3.1-3.14
# 4.1-4.16
# 5.1-5.3까지
#
# 실기:
#   1. 그림 불러오기
#   2. 3.1, 3.2
#   3. 3.2-3.7
#   4. 4장은 다

# %% [markdown]
# 3, 4장 위주로 공부
#
#
# 성능 계산하는 건 안나옴
# 1. 빅데이터 특징 3가제
#   양, 속도, 종류
# 2. 코랩에 그림 삽입 방법
#   img.mping.imread('그림경로')
# 3. 별칭 만들기
#   import numpy as np
#   np_store_a = np.array()(3.2장)
# 4. 넘파이 다차원 배열
#   - 브로드캐스팅(3.2장)
#   - 인덱싱, 슬라이싱
#   - 3.2장 표 외우기, 4가지(shape, size, dtype, itemsize)
#   열 연산하기
#   - 2차원 배열 슬라이싱하기(3.8) 52페이지
#   - 넘파이 2차원 배열을 1차원 만들기
#
#     ex) p=np.array([1.63, 1.86],[76.0, 84.0, 69.0]) h=p[0]   w=p[1]
#   - arange(50) = 0~49
#   - arange(0,10,2)([0,2,4,6,8])
#   - arange(4) ([0,1,2,3])
#   - arange(1,7)([1,2,3,4,5,6])
#   - reshpe 72페이지
#   - 배열 결합
#   - 83페이지 전치행렬
#   - 3.13(87페이지)
#   - 원소 삽입
#   - ex) a = np.array([1,3,4])
#   np.insert(a,1,2) 출력결과: 1,2,3,4
# 5. 4장 넘파이세계로
#   1. 넘파이 함수
#   - 합계(sum)
#   - 평균(mean)
