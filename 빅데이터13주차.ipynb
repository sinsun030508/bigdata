# %%
import pandas as pd

df_1 = pd.DataFrame({
   'name' : ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'horse power' : [130, 250, 190, 300, 210, 220, 170],
    'weight' : [1.9, 2.6, 2.2, 2.9, 2.4, 2.3, 2.2],
    'efficiency': [16.3, 10.2, 11.1, 7.1, 12.1, 13.2, 14.2] })
df_1['com'] = 'P'

df_2 = pd.DataFrame({
   'name' : ['A', 'B', 'C', 'D'],
    'horse power' : [120, 220, 120, 200],
    'weight' : [1.9, 2.1, 1.5, 2.9],
    'efficiency': [18.3, 19.2, 21.1, 17.3] })
df_2['com'] = 'Q'

df_3 = pd.concat([df_1, df_2])
df_3 = df_3.set_index('name')

print(df_3)
# Out:
#       horse power  weight  efficiency com
# name
# A             130     1.9        16.3   P
# B             250     2.6        10.2   P
# C             190     2.2        11.1   P
# D             300     2.9         7.1   P
# E             210     2.4        12.1   P
# F             220     2.3        13.2   P
# G             170     2.2        14.2   P
# A             120     1.9        18.3   Q
# B             220     2.1        19.2   Q
# C             120     1.5        21.1   Q
# D             200     2.9        17.3   Q

# %%
import pandas as pd

path = '/content/sample_data/scores.csv'
df = pd.read_csv(path)

df
# Out:
#        학번   이름  국어   수학  과학
# 0  251101  홍길동  90   90  60
# 1  251102  홍길순  85   90  80
# 2  251103  이철수  50   70  90
# 3  251104  김영희  80   60  70
# 4  251105  정선아  80   78  76
# 5  251106  이정민  80  100  90
# 6  251107  박동윤  70   75  80

# %%
print(df)
# Out:
#        학번   이름  국어   수학  과학
# 0  251101  홍길동  90   90  60
# 1  251102  홍길순  85   90  80
# 2  251103  이철수  50   70  90
# 3  251104  김영희  80   60  70
# 4  251105  정선아  80   78  76
# 5  251106  이정민  80  100  90
# 6  251107  박동윤  70   75  80

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/dongupak/BigDataAnalysis/main/scores.csv'

df = pd.read_csv(url, encoding='UTF-8', index_col=0)
print(df)
# Out:
#          이름  국어   수학  과학
# 학번
# 251101  홍길동  90   90  60
# 251102  홍길순  85   90  80
# 251103  이철수  50   70  90
# 251104  김영희  80   60  70
# 251105  정선아  80   78  76
# 251106  이정민  80  100  90
# 251107  박동윤  70   75  80

# %%
import pandas as pd

path = 'https://raw.githubusercontent.com/dongupak/BigDataAnalysis/main/'

df = pd.read_csv(path + 'scores.csv', encoding='utf-8')
df = df.set_index('학번')

df.head()
# Out:
#          이름  국어  수학  과학
# 학번
# 251101  홍길동  90  90  60
# 251102  홍길순  85  90  80
# 251103  이철수  50  70  90
# 251104  김영희  80  60  70
# 251105  정선아  80  78  76

# %%
import pandas as pd

name_series = pd.Series(['홍길동', '김철수', '이영희'])
age_series = pd.Series([20, 21, 22])
sex_series = pd.Series(['남', '남', '여'])
grade_series = pd.Series([4.2, 3.8, 4.5])

student_df = pd.DataFrame({
    '이름': name_series,
    '나이': age_series,
    '성별': sex_series,
    '평점': grade_series
})

print(student_df)
# Out:
#     이름  나이 성별   평점
# 0  홍길동  20  남  4.2
# 1  김철수  21  남  3.8
# 2  이영희  22  여  4.5

# %%
student_df['이름']
# Out:
# 0    홍길동
# 1    김철수
# 2    이영희
# Name: 이름, dtype: object

# %%
student_df[['이름', '평점']]
# Out:
#     이름   평점
# 0  홍길동  4.2
# 1  김철수  3.8
# 2  이영희  4.5

# %%
import matplotlib.pyplot as plt

student_df['평점'].plot(kind='bar',
                        color=['red', 'blue', 'orange'])

plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

student_df.set_index('이름')['평점'].plot(kind='bar')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
path='/content/sample_data/scores.csv'
df = pd.DataFrame({'실험실':['A','B','C','D'], \
                   '자료값1':[10,30,20,50], '자료값2':[45,50,30,10]})
df.plot.bar(x='실험실', y='자료값1',rot=0)
# Out:
# <Axes: xlabel='실험실'>

# %%
df = pd.DataFrame({'실험실':['A','B','C','D'], \
                   '자료값1':[10,30,20,50], '자료값2':[45,50,30,10]})
df.plot.bar(x='실험실',rot=0)
# Out:
# <Axes: xlabel='실험실'>

# %%
# !apt-get -qq install fonts-nanum

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df.plot.bar(x='실험실', stacked=True)
# Out:
# <Axes: xlabel='실험실'>

# %%
axes = df.plot.bar(rot=0, subplots=True)
axes[1].legend(loc=2)

# %%
df.head()
# Out:
#          이름  국어  수학  과학
# 학번
# 251101  홍길동  90  90  60
# 251102  홍길순  85  90  80
# 251103  이철수  50  70  90
# 251104  김영희  80  60  70
# 251105  정선아  80  78  76

# %%
df[:4]
# Out:
#          이름  국어  수학  과학
# 학번
# 251101  홍길동  90  90  60
# 251102  홍길순  85  90  80
# 251103  이철수  50  70  90
# 251104  김영희  80  60  70

# %%
df.head(4)
df[:4]
df.tail(4)
# Out:
#          이름  국어   수학  과학
# 학번
# 251104  김영희  80   60  70
# 251105  정선아  80   78  76
# 251106  이정민  80  100  90
# 251107  박동윤  70   75  80

# %%
print(df[:4])
print(df[-4:])
# Out:
#          이름  국어  수학  과학
# 학번
# 251101  홍길동  90  90  60
# 251102  홍길순  85  90  80
# 251103  이철수  50  70  90
# 251104  김영희  80  60  70
#          이름  국어   수학  과학
# 학번
# 251104  김영희  80   60  70
# 251105  정선아  80   78  76
# 251106  이정민  80  100  90
# 251107  박동윤  70   75  80

# %%
print(df.iloc[:,0])
print(df.iloc[:,1])
# Out:
# 학번
# 251101    홍길동
# 251102    홍길순
# 251103    이철수
# 251104    김영희
# 251105    정선아
# 251106    이정민
# 251107    박동윤
# Name: 이름, dtype: object
# 학번
# 251101    90
# 251102    85
# 251103    50
# 251104    80
# 251105    80
# 251106    80
# 251107    70
# Name: 국어, dtype: int64

# %%
df.index
# Out:
# Index([251101, 251102, 251103, 251104, 251105, 251106, 251107], dtype='int64', name='학번')

# %%
print(df.loc[df.index > 251102])
# Out:
#          이름  국어   수학  과학
# 학번
# 251103  이철수  50   70  90
# 251104  김영희  80   60  70
# 251105  정선아  80   78  76
# 251106  이정민  80  100  90
# 251107  박동윤  70   75  80

# %%
print(df.loc[df['국어'] > 75])
# Out:
#          이름  국어   수학  과학
# 학번
# 251101  홍길동  90   90  60
# 251102  홍길순  85   90  80
# 251104  김영희  80   60  70
# 251105  정선아  80   78  76
# 251106  이정민  80  100  90

# %%
#시험에 나옴
print(df[(df['국어'] >= 80)&(df['수학']>=80)])
# Out:
#          이름  국어   수학  과학
# 학번
# 251101  홍길동  90   90  60
# 251102  홍길순  85   90  80
# 251106  이정민  80  100  90

# %%
df['합계'] = df.sum(axis=1, numeric_only=True)
df
# Out:
#          이름  국어   수학  과학   합계
# 학번
# 251101  홍길동  90   90  60  480
# 251102  홍길순  85   90  80  510
# 251103  이철수  50   70  90  420
# 251104  김영희  80   60  70  420
# 251105  정선아  80   78  76  468
# 251106  이정민  80  100  90  540
# 251107  박동윤  70   75  80  450

# %%
df['합계'] = df.mean(axis=1, numeric_only=True)
df
# Out:
#          이름  국어   수학  과학     합계
# 학번
# 251101  홍길동  90   90  60  75.00
# 251102  홍길순  85   90  80  83.75
# 251103  이철수  50   70  90  65.00
# 251104  김영희  80   60  70  67.50
# 251105  정선아  80   78  76  77.50
# 251106  이정민  80  100  90  87.50
# 251107  박동윤  70   75  80  73.75

# %%
df['평균'] = df[['국어','수학','과학']].mean(axis=1)
df
# Out:
#          이름  국어   수학  과학     합계    평균
# 학번
# 251101  홍길동  90   90  60  75.00  80.0
# 251102  홍길순  85   90  80  83.75  85.0
# 251103  이철수  50   70  90  65.00  70.0
# 251104  김영희  80   60  70  67.50  70.0
# 251105  정선아  80   78  76  77.50  78.0
# 251106  이정민  80  100  90  87.50  90.0
# 251107  박동윤  70   75  80  73.75  75.0

# %%
sorted_df = df.sort_values('합계', ascending=False)
print(sorted_df)
# Out:
#          이름  국어   수학  과학     합계    평균
# 학번
# 251106  이정민  80  100  90  87.50  90.0
# 251102  홍길순  85   90  80  83.75  85.0
# 251105  정선아  80   78  76  77.50  78.0
# 251101  홍길동  90   90  60  75.00  80.0
# 251107  박동윤  70   75  80  73.75  75.0
# 251104  김영희  80   60  70  67.50  70.0
# 251103  이철수  50   70  90  65.00  70.0

# %%
print('A학점 학생')
print(sorted_df.iloc[:3])
print('\nB학점 학생')
print(sorted_df.iloc[3:5])
print('\nc학점 학생')
print(sorted_df.iloc[5:])
# Out:
# A학점 학생
#          이름  국어   수학  과학     합계    평균
# 학번
# 251106  이정민  80  100  90  87.50  90.0
# 251102  홍길순  85   90  80  83.75  85.0
# 251105  정선아  80   78  76  77.50  78.0
#
# B학점 학생
#          이름  국어  수학  과학     합계    평균
# 학번
# 251101  홍길동  90  90  60  75.00  80.0
# 251107  박동윤  70  75  80  73.75  75.0
#
# c학점 학생
#          이름  국어  수학  과학    합계    평균
# 학번
# 251104  김영희  80  60  70  67.5  70.0
# 251103  이철수  50  70  90  65.0  70.0

# %%
with pd.ExcelWriter('output.xlsx') as writer:
  sorted_df.iloc[:3].to_excel(writer, sheet_name="A학점")
  sorted_df.iloc[3:5].to_excel(writer, sheet_name="B학점")
  sorted_df.iloc[5:].to_excel(writer, sheet_name="AC학점")

# %%
df4 = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'horse power': [130, 250, 190, 300, 210, 220,170],
    'weight': [1.9, 2.6, 2.2, 2.9, 2.4, 2.3, 2.2],
    'efficiency': [16.3, 10.2, 11.1,12.1,13.2,14.2,7.1]
})
df4.plot
# Out:
#   name  horse power  weight  efficiency
# 0    A          130     1.9        16.3
# 1    B          250     2.6        10.2
# 2    C          190     2.2        11.1
# 3    D          300     2.9        12.1
# 4    E          210     2.4        13.2
# 5    F          220     2.3        14.2
# 6    G          170     2.2         7.1

# %%
df4 = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'horse power': [130, 250, 190, 300, 210, 220,170],
    'weight': [1.9, 2.6, 2.2, 2.9, 2.4, 2.3, 2.2],
    'efficiency': [16.3, 10.2, 11.1,12.1,13.2,14.2,7.1]
})
df4=df4.set_index('name')
max_df4 = df4.loc[df4['horse power']==df4['horse power'].max()]

print(max_df4)
# Out:
#       horse power  weight  efficiency
# name
# D             300     2.9        12.1

# %%
df4 = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'horse power': [130, 250, 190, 300, 210, 220,170],
    'weight': [1.9, 2.6, 2.2, 2.9, 2.4, 2.3, 2.2],
    'efficiency': [16.3, 10.2, 11.1,12.1,13.2,14.2,7.1]
})
df4['hpmile']=df4['horse power']*df4['efficiency']
print(df4.loc[df4['hpmile']==df4['hpmile'].max()])
# Out:
#   name  horse power  weight  efficiency  hpmile
# 3    D          300     2.9        12.1  3630.0

# %%
df5 = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'horse power': [130, 250, 190, 300, 210, 220,170],
    'weight': [1.9, 2.6, 2.2, 2.9, 2.4, 2.3, 2.2],
    'efficiency': [16.3, 10.2, 11.1,12.1,13.2,14.2,7.1]
})
df6 =
# Out:
#   name  horse power  weight  efficiency  hpmile
# 1    B          250     2.6        10.2  2550.0
# 2    C          190     2.2        11.1  2109.0
# 3    D          300     2.9        12.1  3630.0
# 4    E          210     2.4        13.2  2772.0
# 5    F          220     2.3        14.2  3124.0
# 6    G          170     2.2         7.1  1207.0
